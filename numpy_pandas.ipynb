# %%
import numpy as np
import pandas as pd

arr = np.array([5,4,3,2,1])

arr[[True, True, False]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-14733a7f77f1> in <module>
#       4 arr = np.array([5,4,3,2,1])
#       5
# ----> 6 arr[[True, True, False]]
#       7
#       8
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 5 but corresponding boolean dimension is 3

# %%
import pandas as pd
import numpy as np

sr = pd.Series([5.1,"4",3,2,1])

sr.name = "My Series"
sr.index
# Out:
# RangeIndex(start=0, stop=5, step=1)
